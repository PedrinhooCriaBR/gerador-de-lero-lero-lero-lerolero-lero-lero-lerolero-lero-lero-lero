# %%
class A:
    a = 1 #publico
    __b = 2 #privado acesso a classe A

class B(A):
    __c = 3 #privado a B

    def __init__(self):
        print(self.a)
        print(self.__c)
a = A()
print(a.a)
# Out:
# 1

# %%
b = B()
print(b.__c)
print(b.__b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 b = B()
#       2 print(b.__c)
#       3 print(b.__b)
#
# NameError: name 'B' is not defined
