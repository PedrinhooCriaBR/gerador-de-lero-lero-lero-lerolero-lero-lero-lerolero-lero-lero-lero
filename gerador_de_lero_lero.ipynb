# %%
import random

# Listas de ideias aleatórias ✨
nomes = ["Aeroporto de mosquito", "Lamapaluzo", "Escorregador de piolho", "cabeça de amolar facão", "cabeça de nos todos", "Sr cabeça", "cabeça de ovo", "bola de cristal"]
armas = ["espada eletrizante", "bazuca", "Canhão de partículas", "Rifle de plasma", "Lançador de buracos negros"]
mascotes = ["Golem de bolso", "Parasita simbiótico", "Corvo das sombras", "Kitsune", "polvo mágico"]
poderes = ["Tempo fragmentados", "Dívida temporal", "Envelhecimento seletivo", "Materialização de pensamentos", "Fusão com o vazio"]

# Blocos de narrativa com lacunas 📝
inicios = [
    "{nome} estava sonhando e ficou preso dentro do sonho e nao consegue mais sair e precisa desvendar um enigma para poder sair de la.",
    "{nome} sofreu um acidente e na sua cabeca dele estava no GTA V e agora para voltar para o mundo real voce precisa zerar o jogo para voltar a viver normalmente.",
    "{nome} estava em uma viagem galatica e foi puxado por um buraco negro ultra massivo e esta preso nele agora e para sair voce precisa saber como criar uma maquina do tempo para poder sair de la com os materias que existem la dentro do buraco negro {mascote}.",
    "{nome} precisa achar todas as pessoas desse genero e dar ola a todos , todas , todes , toddy ,nescal, nesquik ,bom dia a ele , ela , elix , asterix , obelix , tinky-winky , lala , pros teletubbies , bom dia aos binarios , nao binarios , centenarios , bilionarios , bom dia aos lgbt , sbt , cpc , spc , bom dia aos simpatizantes , aos amantes , hidrantes , fertilizantes ,  bom dia as outras , outres , aos outros ,  aos dois , tres, quatro , cinco , seis , sete , oito , ta na hora de molhar o biscoito , bom dia a voces."
]

desafios = [
    "Seu desafio e derrotar o {mascote} usando o {poder}.",
    "Seu desafio e zoar o {nome} ate ele se desviver e acabar com a vida dele.",
    "Seu desafio e formar um grupo com {nome} e fazer uma plantaçao de dro#@!.",
]

finais = [
    "voce nao conseguiu plantar e faliu e perdeu sua casa.",
    "Voce zoou tanto o {nome} que ele se desviveu e voce se arrependeu e se deviveu tmb por conta da tristeza eterna que voce tera.",
    "Voce nao conseguiu dar ola a todos os generos e eles se revoltaram contra voce pois voce foi machista, feminista, arrogante, ignorante e vai ser exposto no twitter.",
]

# Sorteia os elementos aleatórios 🎲
nome = random.choice(nomes)
arma = random.choice(armas)
mascote = random.choice(mascotes)
poder = random.choice(poderes)
inicio = random.choice(inicios).format(nome=nome, mascote=mascote)
desafio = random.choice(desafios).format(nome=nome, arma=arma, poder=poder, mascote=mascote)
final = random.choice(finais).format(nome=nome, mascote=mascote, arma=arma, poder=poder)

# Apresenta a história 💬
print("🎮 BEM-VINDO AO RPG RANDOMIZADO! 🎮\n")
print(f"✨ Nome do herói: {nome}")
print(f"🧸 Mascote: {mascote}")
print(f"⚔️ Arma mágica: {arma}")
print(f"🌀 Superpoder: {poder}\n")

print("📖 AVENTURA:")
print(inicio)
print(desafio)

print("\n⚔️ ESCOLHA FINAL:")
print("1 - Confiar no mascote")
print("2 - Atacar com a arma mágica")

escolha = input("digite sua escolha")

if escolha == "1":
    print(f"\n{mascote} revela seu poder oculto e salva {nome} em um ato heróico! 🐉")
else:
    print(f"\nCom coragem, {nome} usa a {arma} e libera todo o poder de {poder}! 💥")

print("\n🌟 FINAL:")
print(final)
# Out:
# 🎮 BEM-VINDO AO RPG RANDOMIZADO! 🎮
#
# ✨ Nome do herói: cabeça de amolar facão
# 🧸 Mascote: polvo mágico
# ⚔️ Arma mágica: espada eletrizante
# 🌀 Superpoder: Materialização de pensamentos
#
# 📖 AVENTURA:
# cabeça de amolar facão estava sonhando e ficou preso dentro do sonho e nao consegue mais sair e precisa desvendar um enigma para poder sair de la.
# Seu desafio e derrotar o polvo mágico usando o Materialização de pensamentos.
#
# ⚔️ ESCOLHA FINAL:
# 1 - Confiar no mascote
# 2 - Atacar com a arma mágica
#
# Com coragem, cabeça de amolar facão usa a espada eletrizante e libera todo o poder de Materialização de pensamentos! 💥
#
# 🌟 FINAL:
# Voce nao conseguiu dar ola a todos os generos e eles se revoltaram contra voce pois voce foi machista, feminista, arrogante, ignorante e vai ser exposto no twitter.
